# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
# !pip install torchsummary
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
import torchvision.transforms as transforms
from torchvision.transforms import RandomApply, RandomHorizontalFlip
import torchvision.models as models
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
# !pip install git+https://github.com/lartpang/PySODMetrics.git
from py_sod_metrics import Fmeasure
# !pip install git+https://github.com/Po-Hsun-Su/pytorch-ssim.git
import pytorch_ssim
import shutil
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1
# 2024-05-26 09:09:00.807855: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-26 09:09:00.807973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-26 09:09:00.934705: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Collecting git+https://github.com/lartpang/PySODMetrics.git
#   Cloning https://github.com/lartpang/PySODMetrics.git to /tmp/pip-req-build-2yqyjzz8
#   Running command git clone --filter=blob:none --quiet https://github.com/lartpang/PySODMetrics.git /tmp/pip-req-build-2yqyjzz8
#   Resolved https://github.com/lartpang/PySODMetrics.git to commit 4b1091a474133a4dfd3b1220b63a6669c8b1e774
# done
# done
# done
# Requirement already satisfied: scipy<2,>=1.5 in /opt/conda/lib/python3.10/site-packages (from pysodmetrics==1.4.2) (1.11.4)
# Requirement already satisfied: numpy<2,>=1.18 in /opt/conda/lib/python3.10/site-packages (from pysodmetrics==1.4.2) (1.26.4)
# Building wheels for collected packages: pysodmetrics
# done
#   Created wheel for pysodmetrics: filename=pysodmetrics-1.4.2-py3-none-any.whl size=16108 sha256=58a11e5e76001e0ac459fb25cc5a99db890c6730b491f897dd19559df78c3eec
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i_jey9ij/wheels/05/9f/5b/1f408258fcd0b5808871e08e28be7e42641780675d753c1932
# Successfully built pysodmetrics
# Installing collected packages: pysodmetrics
# Successfully installed pysodmetrics-1.4.2
# Collecting git+https://github.com/Po-Hsun-Su/pytorch-ssim.git
#   Cloning https://github.com/Po-Hsun-Su/pytorch-ssim.git to /tmp/pip-req-build-_kd58jja
#   Running command git clone --filter=blob:none --quiet https://github.com/Po-Hsun-Su/pytorch-ssim.git /tmp/pip-req-build-_kd58jja
#   Resolved https://github.com/Po-Hsun-Su/pytorch-ssim.git to commit 3add4532d3f633316cba235da1c69e90f0dfb952
# done
# Building wheels for collected packages: pytorch_ssim
# done
#   Created wheel for pytorch_ssim: filename=pytorch_ssim-0.1-py3-none-any.whl size=2307 sha256=cb15795de53d44ff07b95558dd35743fa946092fbfa78f8c1626d2fe5bd04b61
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n1c8m7ou/wheels/99/53/8e/13474869f278024f6ed5791806bdfe47cfde59f30fe0bc6dd5
# Successfully built pytorch_ssim
# Installing collected packages: pytorch_ssim
# Successfully installed pytorch_ssim-0.1

# %%
class GeneralDataset(Dataset): # 用於 training set 和 validation set 的 Dataset
    def __init__(self, path_list, img_size, mode='train'):
      assert mode in ['train', 'val'] # mode 必須是' train' 或 'val'
      self.img_size = img_size
      self.mode = mode
      self.images = []
      self.labels = []
      self.filter_files(path_list)

      self.da_transform = transforms.Compose([
            RandomApply([RandomHorizontalFlip()], p=0.5)
      ])

      # image 預處理操作: 調整大小、轉換為 Tensor、標準化
      self.img_transform = transforms.Compose([
          transforms.ToTensor(),
          transforms.Resize((self.img_size, self.img_size) , antialias = True),
          transforms.Grayscale(num_output_channels = 1),
      ])
#           
#           transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

      # ground truth 預處理操作: 調整大小並轉換為 Tensor
      self.label_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Resize((self.img_size, self.img_size) , antialias = True),
      ])
        
      self.to_tensor = transforms.Compose([
            transforms.ToTensor(),
      ])

    def __getitem__(self, index):
      image = cv2.imread(self.images[index] , cv2.IMREAD_GRAYSCALE)
#       image = Image.open(self.images[index]).convert('RGB')# 打開圖像文件，轉換為RGB
#       gray_image = Image.open(self.images[index]).convert('L')# 打開圖像文件，轉換為RGB
#       label = Image.open(self.labels[index]).convert('L')# 打開圖像文件，轉換為灰階影像
      label = cv2.imread(self.labels[index] , cv2.IMREAD_GRAYSCALE)

      # 若為訓練模式，進行資料擴增
      kernel_size = 3
      image = cv2.GaussianBlur(image,(kernel_size, kernel_size), 0)
      image = cv2.Canny(image , 100 , 200 , L2gradient = True)

      if self.mode == "train":
#         image.convert('RGB')
        seed = torch.random.initial_seed()
        torch.manual_seed(seed)
#         image = self.da_transform(image)
        torch.manual_seed(seed)
#         label = self.da_transform(label)
      image = self.img_transform(image)
#       gray_image = self.img_transform(gray_image)
      label = self.label_transform(label)
      return image, label

    def filter_files(self , path):
      images, labels = [], []
      for path_pair in path :
          img = Image.open(path_pair[0])
          label = Image.open(path_pair[1])
          if img.size == label.size:
              images.append(path_pair[0])
              labels.append(path_pair[1])
      self.images, self.labels = images, labels

    def __len__(self):
        return len(self.images)
    
class TestlDataset(Dataset):# 用於 testing set 的 Dataset
    def __init__(self, image_root, img_size):
      self.images = sorted([os.path.join(image_root, f) for f in os.listdir(image_root) if f.endswith('.jpg')])
      self.img_size = img_size
      self.img_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((self.img_size, self.img_size) , antialias = True),
      ])
    def __getitem__(self, index):
#       image = Image.open(self.images[index]).convert('L')# 打開圖像文件，轉換為 RGB
      image = cv2.imread(self.images[index] , cv2.IMREAD_GRAYSCALE)
      kernel_size = 3
      image = cv2.GaussianBlur(image,(kernel_size, kernel_size), 0)
      image = cv2.Canny(image , 100 , 200 , L2gradient = True)
    
      image = self.img_transform(image)
      name = os.path.basename(self.images[index]).replace('.jpg', '.png')# 獲取圖像的文件名，並替換後綴
      return image, name
    def __len__(self):
      return len(self.images)

# %%
class DecoderBlock(nn.Module):
    def __init__(self, in_channel, mid_channel, out_channel, kernel_size, dilation, padding, upsample):
        super(DecoderBlock, self).__init__()

        modules = [
            nn.Conv2d(in_channel, mid_channel, kernel_size=kernel_size, dilation=dilation, padding=padding),
            nn.BatchNorm2d(mid_channel),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channel, mid_channel, kernel_size=kernel_size, dilation=dilation, padding=padding),
            nn.BatchNorm2d(mid_channel),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channel, out_channel, kernel_size=kernel_size, dilation=dilation, padding=padding),
            nn.BatchNorm2d(out_channel),
            nn.ReLU(inplace=True)
        ]
        #如果upsample=True，則會做upsmapling
        if upsample:
            modules.append(nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False))

        self.block = nn.Sequential(*modules)

    def forward(self, x):
        return self.block(x)

class SimpleModel(nn.Module):
    def __init__(self, n_channels, n_classes):
        super(SimpleModel, self).__init__()

        # 載入resnet34作為pre-trainded model
#         resnet = models.vgg19(pretrained=True)
#         resnet = models.resnet18(pretrained=True)
        resnet = models.resnet34(pretrained=True)
#         resnet = models.resnet50(pretrained=True)
#         resnet = models.resnet101(pretrained=True)

        ## -------------Encoder--------------
        self.inconv = nn.Conv2d(n_channels, 64, 3, padding=1)
        self.inbn = nn.BatchNorm2d(64)
        self.inrelu = nn.ReLU(inplace=True)

        self.encoder1 = resnet.layer1
        self.encoder2 = resnet.layer2
        self.encoder3 = resnet.layer3
        self.encoder4 = resnet.layer4
        
        
        
#         # vgg19
#         ##-------------Bridge--------------
#         self.bridge = DecoderBlock(512, 512, 512, 3, dilation=2, padding=2, upsample=False)

#         ## -------------Decoder--------------
#         self.decoder4 = DecoderBlock(1024, 512, 512, 3, dilation=1, padding=1, upsample=True)
#         self.decoder3 = DecoderBlock(1024, 512, 256, 3, dilation=1, padding=1, upsample=True)
#         self.decoder2 = DecoderBlock(512, 256, 128, 3, dilation=1, padding=1, upsample=True)
#         self.decoder1 = DecoderBlock(256, 128, 64, 3, dilation=1, padding=1, upsample=False)


        
        # resnet34
        ##-------------Bridge--------------
        self.bridge = DecoderBlock(512, 512, 512, 3, dilation=2, padding=2, upsample=False)

        ## -------------Decoder--------------
        self.decoder4 = DecoderBlock(1024, 512, 256, 3, dilation=1, padding=1, upsample=True)
        self.decoder3 = DecoderBlock(512, 256, 128, 3, dilation=1, padding=1, upsample=True)
        self.decoder2 = DecoderBlock(256, 128, 64, 3, dilation=1, padding=1, upsample=True)
        self.decoder1 = DecoderBlock(128, 64, 64, 3, dilation=1, padding=1, upsample=False)



#         # resnet50
#         ## -------------Bridge--------------
#         self.bridge = DecoderBlock(2048, 2048, 2048, 3, dilation=2, padding=2, upsample=False)

#         ## -------------Decoder--------------
#         self.decoder4 = DecoderBlock(4096, 2048, 1024, 3, dilation=1, padding=1, upsample=True)
#         self.decoder3 = DecoderBlock(2048, 1024, 512, 3, dilation=1, padding=1, upsample=True)
#         self.decoder2 = DecoderBlock(1024, 512, 256, 3, dilation=1, padding=1, upsample=True)
#         self.decoder1 = DecoderBlock(512, 256, 64, 3, dilation=1, padding=1, upsample=False)



#         # resnet101
#         ## -------------Bridge--------------
#         self.bridge = DecoderBlock(2048, 2048, 2048, 3, dilation=2, padding=2, upsample=False)

#         ## -------------Decoder--------------
#         self.decoder4 = DecoderBlock(4096, 2048, 1024, 3, dilation=1, padding=1, upsample=True)
#         self.decoder3 = DecoderBlock(2048, 1024, 512, 3, dilation=1, padding=1, upsample=True)
#         self.decoder2 = DecoderBlock(1024, 512, 256, 3, dilation=1, padding=1, upsample=True)
#         self.decoder1 = DecoderBlock(512, 256, 64, 3, dilation=1, padding=1, upsample=False)



        ## -------------Final Convolution Layer--------------
        self.final_conv = nn.Conv2d(64, n_classes, 3, padding=1)

    def forward(self, x):
        hx = self.inrelu(self.inbn(self.inconv(x)))

        e1 = self.encoder1(hx)
        e2 = self.encoder2(e1)
        e3 = self.encoder3(e2)
        e4 = self.encoder4(e3)

        b = self.bridge(e4)

        d4 = self.decoder4(torch.cat((e4, b), dim=1))
        d3 = self.decoder3(torch.cat((e3, d4), dim=1))
        d2 = self.decoder2(torch.cat((e2, d3), dim=1))
        d1 = self.decoder1(torch.cat((e1, d2), dim=1))

        out = self.final_conv(d1)

        return torch.sigmoid(out)

# %%
# 指定 training set 和 validation set 的路徑
tr_image_root = "/kaggle/input/aicup-data/train/train/Training_dataset/img"
tr_label_root = "/kaggle/input/aicup-data/train/train/Training_dataset/label_img"

train_image_list = sorted([os.path.join(tr_image_root, f) for f in os.listdir(tr_image_root) if f.endswith('.jpg')])
train_label_list = sorted([os.path.join(tr_label_root, f) for f in os.listdir(tr_label_root) if f.endswith('.png')])

# # 因需切割 train data 為 train 與 validation，所以需先讀入data並切割
# # 讀資料
# import glob
# # 找出 train_path 底下所有檔案
# train_image_list = glob.glob(os.path.join(tr_image_root , '*.*') , recursive = True)
# train_label_list = glob.glob(os.path.join(tr_label_root , '*.*') , recursive = True)
l = list(zip(train_image_list , train_label_list))

# 切割
from sklearn.model_selection import train_test_split
train_path_list , val_path_list = train_test_split(l , test_size = 0.2 , random_state = 42)

# %%
# 使用 DataLoader 來包裝 training set 和 validation set
# - mode: 設置數據集的模式，設定為 "train "則會做資料擴增
tr_datastet = GeneralDataset(train_path_list,img_size=224, mode="train")
val_datastet = GeneralDataset(val_path_list,img_size=224, mode="val")

# 建立DataLoader來加載 training set 和 validation set
tr_loader = DataLoader(dataset = tr_datastet, batch_size=4, shuffle=True,
                  num_workers=2, pin_memory=True)
val_loader = DataLoader(dataset = val_datastet, batch_size=4, shuffle=True,
                  num_workers=2, pin_memory=True)

# %%
# 檢查 DataLoader 是否成功載入 image 和 ground truth
data_iter = iter(tr_loader)
images, labels = next(data_iter)


image, label = images[0], labels[0]


image = image.numpy()
label = label.numpy()
image = np.transpose(image, (1, 2, 0))
label = np.transpose(label, (1, 2, 0))

if image.min() < 0 or image.max() > 1:
    image = (image - image.min()) / (image.max() - image.min())
plt.imshow(image, cmap='gray')
plt.show()
plt.imshow(label, cmap='gray')
plt.show()

# %%
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
import segmentation_models_pytorch as smp
# !pip install git+https://github.com/qubvel/segmentation_models
# import segmentation_models as smp
# Out:
# Collecting git+https://github.com/qubvel/segmentation_models.pytorch
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-6vesh5p2
#   Running command git clone --filter=blob:none --quiet https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-6vesh5p2
#   Resolved https://github.com/qubvel/segmentation_models.pytorch to commit 3bf4d6ef2bc9d41c2ab3436838aa22375dd0f23a
# done
# done
# done
# Requirement already satisfied: torchvision>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from segmentation_models_pytorch==0.3.3) (0.16.2)
# Collecting pretrainedmodels==0.7.4 (from segmentation_models_pytorch==0.3.3)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.6 MB/s eta 0:00:00
# done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation_models_pytorch==0.3.3)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# done
# Collecting timm==0.9.7 (from segmentation_models_pytorch==0.3.3)
#   Downloading timm-0.9.7-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from segmentation_models_pytorch==0.3.3) (4.66.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from segmentation_models_pytorch==0.3.3) (9.5.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from segmentation_models_pytorch==0.3.3) (1.16.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (2.1.2)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation_models_pytorch==0.3.3)
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from timm==0.9.7->segmentation_models_pytorch==0.3.3) (6.0.1)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from timm==0.9.7->segmentation_models_pytorch==0.3.3) (0.22.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from timm==0.9.7->segmentation_models_pytorch==0.3.3) (0.4.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.5.0->segmentation_models_pytorch==0.3.3) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.5.0->segmentation_models_pytorch==0.3.3) (2.31.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->timm==0.9.7->segmentation_models_pytorch==0.3.3) (21.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch==0.3.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch==0.3.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch==0.3.3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch==0.3.3) (2024.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub->timm==0.9.7->segmentation_models_pytorch==0.3.3) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch==0.3.3) (1.3.0)
# Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 45.1 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: segmentation_models_pytorch, efficientnet-pytorch, pretrainedmodels
# done
#   Created wheel for segmentation_models_pytorch: filename=segmentation_models_pytorch-0.3.3-py3-none-any.whl size=106718 sha256=284f60c2f51e2a3fc1178ab9c590805c454d3ea01864ae86fbca96bc589c1ce3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3af4n499/wheels/1a/49/5f/858bc2741660e381e83f1d8b297edc4d9f0561f29becaee577
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=248284a8da6ad724af0d363444156a38c8f531a9be09187e017585b8a2144f01
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=84735cd1fab187312ef2a26e739fade06b56a732121c5f93ed3015fe08b89333
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built segmentation_models_pytorch efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, efficientnet-pytorch, timm, pretrainedmodels, segmentation_models_pytorch
#   Attempting uninstall: timm
#     Found existing installation: timm 0.9.16
#     Uninstalling timm-0.9.16:
#       Successfully uninstalled timm-0.9.16
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 pretrainedmodels-0.7.4 segmentation_models_pytorch-0.3.3 timm-0.9.7

# %%
# DeepLabV3Plus
model = smp.Unet('resnet50', in_channels=1 , classes=1, activation='sigmoid', encoder_weights='imagenet', decoder_use_batchnorm=True)
# model = SimpleModel(n_channels=1,n_classes = 1)
model.load_state_dict(torch.load("/kaggle/input/unet-resnet50-100epoch-canny/unet_resnet50_100epoch_canny.pth"))
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
summary(model, (1, 224, 224))

class IOU(nn.Module):
    def __init__(self, size_average=True):
        super(IOU, self).__init__()
        self.size_average = size_average

    def forward(self, pred, target):
        b = pred.shape[0]
        IoU = 0.0
        for i in range(b):
            Iand1 = torch.sum(target[i, :, :, :] * pred[i, :, :, :])
            Ior1 = torch.sum(target[i, :, :, :]) + torch.sum(pred[i, :, :, :]) - Iand1
            IoU1 = Iand1 / Ior1
            IoU += (1 - IoU1)
        return IoU / b if self.size_average else IoU


iou_loss_module = IOU(size_average=True)
bce_loss_module = nn.BCEWithLogitsLoss()
ssim_loss_module = pytorch_ssim.SSIM(window_size=11,size_average=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 296MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           3,136
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
#    ResNetEncoder-173  [[-1, 1, 224, 224], [-1, 64, 112, 112], [-1, 256, 56, 56], [-1, 512, 28, 28], [-1, 1024, 14, 14], [-1, 2048, 7, 7]]               0
#         Identity-174           [-1, 2048, 7, 7]               0
#         Identity-175         [-1, 3072, 14, 14]               0
#        Attention-176         [-1, 3072, 14, 14]               0
#           Conv2d-177          [-1, 256, 14, 14]       7,077,888
#      BatchNorm2d-178          [-1, 256, 14, 14]             512
#             ReLU-179          [-1, 256, 14, 14]               0
#           Conv2d-180          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-181          [-1, 256, 14, 14]             512
#             ReLU-182          [-1, 256, 14, 14]               0
#         Identity-183          [-1, 256, 14, 14]               0
#        Attention-184          [-1, 256, 14, 14]               0
#     DecoderBlock-185          [-1, 256, 14, 14]               0
#         Identity-186          [-1, 768, 28, 28]               0
#        Attention-187          [-1, 768, 28, 28]               0
#           Conv2d-188          [-1, 128, 28, 28]         884,736
#      BatchNorm2d-189          [-1, 128, 28, 28]             256
#             ReLU-190          [-1, 128, 28, 28]               0
#           Conv2d-191          [-1, 128, 28, 28]         147,456
#      BatchNorm2d-192          [-1, 128, 28, 28]             256
#             ReLU-193          [-1, 128, 28, 28]               0
#         Identity-194          [-1, 128, 28, 28]               0
#        Attention-195          [-1, 128, 28, 28]               0
#     DecoderBlock-196          [-1, 128, 28, 28]               0
#         Identity-197          [-1, 384, 56, 56]               0
#        Attention-198          [-1, 384, 56, 56]               0
#           Conv2d-199           [-1, 64, 56, 56]         221,184
#      BatchNorm2d-200           [-1, 64, 56, 56]             128
#             ReLU-201           [-1, 64, 56, 56]               0
#           Conv2d-202           [-1, 64, 56, 56]          36,864
#      BatchNorm2d-203           [-1, 64, 56, 56]             128
#             ReLU-204           [-1, 64, 56, 56]               0
#         Identity-205           [-1, 64, 56, 56]               0
#        Attention-206           [-1, 64, 56, 56]               0
#     DecoderBlock-207           [-1, 64, 56, 56]               0
#         Identity-208        [-1, 128, 112, 112]               0
#        Attention-209        [-1, 128, 112, 112]               0
#           Conv2d-210         [-1, 32, 112, 112]          36,864
#      BatchNorm2d-211         [-1, 32, 112, 112]              64
#             ReLU-212         [-1, 32, 112, 112]               0
#           Conv2d-213         [-1, 32, 112, 112]           9,216
#      BatchNorm2d-214         [-1, 32, 112, 112]              64
#             ReLU-215         [-1, 32, 112, 112]               0
#         Identity-216         [-1, 32, 112, 112]               0
#        Attention-217         [-1, 32, 112, 112]               0
#     DecoderBlock-218         [-1, 32, 112, 112]               0
#           Conv2d-219         [-1, 16, 224, 224]           4,608
#      BatchNorm2d-220         [-1, 16, 224, 224]              32
#             ReLU-221         [-1, 16, 224, 224]               0
#           Conv2d-222         [-1, 16, 224, 224]           2,304
#      BatchNorm2d-223         [-1, 16, 224, 224]              32
#             ReLU-224         [-1, 16, 224, 224]               0
#         Identity-225         [-1, 16, 224, 224]               0
#        Attention-226         [-1, 16, 224, 224]               0
#     DecoderBlock-227         [-1, 16, 224, 224]               0
#      UnetDecoder-228         [-1, 16, 224, 224]               0
#           Conv2d-229          [-1, 1, 224, 224]             145
#         Identity-230          [-1, 1, 224, 224]               0
#          Sigmoid-231          [-1, 1, 224, 224]               0
#       Activation-232          [-1, 1, 224, 224]               0
# ================================================================
# Total params: 32,514,833
# Trainable params: 32,514,833
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 463.01
# Params size (MB): 124.03
# Estimated Total Size (MB): 587.24
# ----------------------------------------------------------------

# %%
#設定權重儲存的路徑
save_path = './models'
os.makedirs(save_path, exist_ok=True)


device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
epoch_num = 50
optimizer = optim.Adam(model.parameters(), lr=0.001)

# loss為無限大
best_val_loss = float('inf')

# 紀錄loss
train_loss_list = []
val_loss_list = []
fm_score_list = []

for epoch in range(epoch_num):
    ## -------------Training stage--------------
    model.train()
    loss_all = 0
    epoch_step = 0
    for images , labels in tr_loader:
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss_iou = iou_loss_module(outputs, labels)
        loss_bce = bce_loss_module(outputs, labels)
        ssim_loss = 1 - ssim_loss_module(outputs,labels)
        loss = loss_iou + loss_bce + ssim_loss
        loss.backward()
        optimizer.step()

        epoch_step += 1
        loss_all += loss.item()

    avg_train_loss = loss_all / epoch_step
    train_loss_list.append(avg_train_loss)

    ## -------------Validation stage--------------
    model.eval()
    with torch.no_grad():
        val_loss_all = 0
        val_step = 0
        
        fm_score_all = 0

        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss_iou = iou_loss_module(outputs, labels)
            loss_bce = bce_loss_module(outputs, labels)
            ssim_loss = 1 - ssim_loss_module(outputs,labels)
            val_loss = loss_iou + loss_bce + ssim_loss

            val_loss_all += val_loss.item()
            val_step += 1

        avg_val_loss = val_loss_all / val_step
        val_loss_list.append(avg_val_loss)

    # 儲存最好的權重
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_model_path = os.path.join(save_path, f'best_model.pth')
        torch.save(model.state_dict(), best_model_path)
        print('New best model saved at epoch', epoch + 1)
        
    print(f"Epoch [{epoch+1}/{epoch_num}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")
# Out:
# New best model saved at epoch 1
# Epoch [1/50], Train Loss: 1.2680, Val Loss: 1.3283
# Epoch [2/50], Train Loss: 1.2657, Val Loss: 1.3299
# New best model saved at epoch 3
# Epoch [3/50], Train Loss: 1.2649, Val Loss: 1.3249
# Epoch [4/50], Train Loss: 1.2682, Val Loss: 1.3253
# Epoch [5/50], Train Loss: 1.2615, Val Loss: 1.3292
# Epoch [6/50], Train Loss: 1.2595, Val Loss: 1.3276
# Epoch [7/50], Train Loss: 1.2586, Val Loss: 1.3288
# Epoch [8/50], Train Loss: 1.2570, Val Loss: 1.3301
# Epoch [9/50], Train Loss: 1.2585, Val Loss: 1.3268
# Epoch [10/50], Train Loss: 1.2569, Val Loss: 1.3300
# Epoch [11/50], Train Loss: 1.2547, Val Loss: 1.3251
# Epoch [12/50], Train Loss: 1.2528, Val Loss: 1.3304
# Epoch [13/50], Train Loss: 1.2505, Val Loss: 1.3265
# Epoch [14/50], Train Loss: 1.2506, Val Loss: 1.3282
# Epoch [15/50], Train Loss: 1.2508, Val Loss: 1.3261
# Epoch [16/50], Train Loss: 1.2483, Val Loss: 1.3279
# Epoch [17/50], Train Loss: 1.2474, Val Loss: 1.3300
# Epoch [18/50], Train Loss: 1.2456, Val Loss: 1.3261
# Epoch [19/50], Train Loss: 1.2438, Val Loss: 1.3251
# Epoch [20/50], Train Loss: 1.2436, Val Loss: 1.3260
# Epoch [21/50], Train Loss: 1.2395, Val Loss: 1.3276
# Epoch [22/50], Train Loss: 1.2407, Val Loss: 1.3383
# Epoch [23/50], Train Loss: 1.2423, Val Loss: 1.3302
# Epoch [24/50], Train Loss: 1.2364, Val Loss: 1.3270
# Epoch [25/50], Train Loss: 1.2358, Val Loss: 1.3253
# Epoch [26/50], Train Loss: 1.2335, Val Loss: 1.3387
# Epoch [27/50], Train Loss: 1.2335, Val Loss: 1.3307
# Epoch [28/50], Train Loss: 1.2319, Val Loss: 1.3253
# Epoch [29/50], Train Loss: 1.2292, Val Loss: 1.3304
# New best model saved at epoch 30
# Epoch [30/50], Train Loss: 1.2324, Val Loss: 1.3244
# Epoch [31/50], Train Loss: 1.2277, Val Loss: 1.3294
# Epoch [32/50], Train Loss: 1.2243, Val Loss: 1.3283
# Epoch [33/50], Train Loss: 1.2248, Val Loss: 1.3307
# Epoch [34/50], Train Loss: 1.2246, Val Loss: 1.3294
# Epoch [35/50], Train Loss: 1.2197, Val Loss: 1.3274
# Epoch [36/50], Train Loss: 1.2253, Val Loss: 1.3284
# Epoch [37/50], Train Loss: 1.2197, Val Loss: 1.3262
# Epoch [38/50], Train Loss: 1.2166, Val Loss: 1.3257
# Epoch [39/50], Train Loss: 1.2159, Val Loss: 1.3266
# Epoch [40/50], Train Loss: 1.2122, Val Loss: 1.3320
# Epoch [41/50], Train Loss: 1.2112, Val Loss: 1.3308
# Epoch [42/50], Train Loss: 1.2109, Val Loss: 1.3296
# Epoch [43/50], Train Loss: 1.2117, Val Loss: 1.3277
# Epoch [44/50], Train Loss: 1.2086, Val Loss: 1.3276
# Epoch [45/50], Train Loss: 1.2076, Val Loss: 1.3301
# Epoch [46/50], Train Loss: 1.2057, Val Loss: 1.3271
# Epoch [47/50], Train Loss: 1.2038, Val Loss: 1.3298
# Epoch [48/50], Train Loss: 1.2039, Val Loss: 1.3262
# Epoch [49/50], Train Loss: 1.1998, Val Loss: 1.3261
# Epoch [50/50], Train Loss: 1.1990, Val Loss: 1.3281

# %%
test_image_root = "/kaggle/input/aicup-data/test/test/img"
ts_dataset = TestlDataset(image_root=test_image_root, img_size=224)
ts_loader = DataLoader(dataset=ts_dataset, batch_size=4, shuffle=False, num_workers=2, pin_memory=True)
model = smp.Unet('resnet50', in_channels=1 , classes=1, activation='sigmoid', encoder_weights='imagenet', decoder_use_batchnorm=True)
# model = SimpleModel(n_channels=1, n_classes=1)
# model = smp.Unet++("resnet34", encoder_weights="imagenet", activation=None)
# model = smp.Unet('resnet34', classes=1, activation='sigmoid', encoder_weights='imagenet', decoder_use_batchnorm=True)
model.load_state_dict(torch.load("/kaggle/working/models/best_model.pth"))
model.cuda()
model.eval()
save_path = "./result"
os.makedirs(save_path, exist_ok=True)

with torch.no_grad():
    for images, names in ts_loader:
      images = images.cuda()
      results = model(images)
      results = F.interpolate(results, size=(240, 428), mode='bilinear', align_corners=False)
      results = results.data.cpu().numpy()
      for idx, name in enumerate(names):
          res = results[idx].squeeze()
          success = cv2.imwrite(os.path.join(save_path, name), res * 255)
          if success:
              print(f"File saved successfully: {name}")
          else:
              print(f"Failed to save file: {name}")

#壓縮檔案成zip檔
directory_to_compress = './result'
shutil.make_archive('submission_file', 'zip', directory_to_compress)
# Out:
# File saved successfully: PUB_RI_2000000.png
# File saved successfully: PUB_RI_2000001.png
# File saved successfully: PUB_RI_2000002.png
# File saved successfully: PUB_RI_2000003.png
# File saved successfully: PUB_RI_2000004.png
# File saved successfully: PUB_RI_2000005.png
# File saved successfully: PUB_RI_2000006.png
# File saved successfully: PUB_RI_2000007.png
# File saved successfully: PUB_RI_2000008.png
# File saved successfully: PUB_RI_2000009.png
# File saved successfully: PUB_RI_2000010.png
# File saved successfully: PUB_RI_2000011.png
# File saved successfully: PUB_RI_2000012.png
# File saved successfully: PUB_RI_2000013.png
# File saved successfully: PUB_RI_2000014.png
# File saved successfully: PUB_RI_2000015.png
# File saved successfully: PUB_RI_2000016.png
# File saved successfully: PUB_RI_2000017.png
# File saved successfully: PUB_RI_2000018.png
# File saved successfully: PUB_RI_2000019.png
# File saved successfully: PUB_RI_2000020.png
# File saved successfully: PUB_RI_2000021.png
# File saved successfully: PUB_RI_2000022.png
# File saved successfully: PUB_RI_2000023.png
# File saved successfully: PUB_RI_2000024.png
# File saved successfully: PUB_RI_2000025.png
# File saved successfully: PUB_RI_2000026.png
# File saved successfully: PUB_RI_2000027.png
# File saved successfully: PUB_RI_2000028.png
# File saved successfully: PUB_RI_2000029.png
# File saved successfully: PUB_RI_2000030.png
# File saved successfully: PUB_RI_2000031.png
# File saved successfully: PUB_RI_2000032.png
# File saved successfully: PUB_RI_2000033.png
# File saved successfully: PUB_RI_2000034.png
# File saved successfully: PUB_RI_2000035.png
# File saved successfully: PUB_RI_2000036.png
# File saved successfully: PUB_RI_2000037.png
# File saved successfully: PUB_RI_2000038.png
# File saved successfully: PUB_RI_2000039.png
# File saved successfully: PUB_RI_2000040.png
# File saved successfully: PUB_RI_2000041.png
# File saved successfully: PUB_RI_2000042.png
# File saved successfully: PUB_RI_2000043.png
# File saved successfully: PUB_RI_2000044.png
# File saved successfully: PUB_RI_2000045.png
# File saved successfully: PUB_RI_2000046.png
# File saved successfully: PUB_RI_2000047.png
# File saved successfully: PUB_RI_2000048.png
# File saved successfully: PUB_RI_2000049.png
# File saved successfully: PUB_RI_2000050.png
# File saved successfully: PUB_RI_2000051.png
# File saved successfully: PUB_RI_2000052.png
# File saved successfully: PUB_RI_2000053.png
# File saved successfully: PUB_RI_2000054.png
# File saved successfully: PUB_RI_2000055.png
# File saved successfully: PUB_RI_2000056.png
# File saved successfully: PUB_RI_2000057.png
# File saved successfully: PUB_RI_2000058.png
# File saved successfully: PUB_RI_2000059.png
# File saved successfully: PUB_RI_2000060.png
# File saved successfully: PUB_RI_2000061.png
# File saved successfully: PUB_RI_2000062.png
# File saved successfully: PUB_RI_2000063.png
# File saved successfully: PUB_RI_2000064.png
# File saved successfully: PUB_RI_2000065.png
# File saved successfully: PUB_RI_2000066.png
# File saved successfully: PUB_RI_2000067.png
# File saved successfully: PUB_RI_2000068.png
# File saved successfully: PUB_RI_2000069.png
# File saved successfully: PUB_RI_2000070.png
# File saved successfully: PUB_RI_2000071.png
# File saved successfully: PUB_RI_2000072.png
# File saved successfully: PUB_RI_2000073.png
# File saved successfully: PUB_RI_2000074.png
# File saved successfully: PUB_RI_2000075.png
# File saved successfully: PUB_RI_2000076.png
# File saved successfully: PUB_RI_2000077.png
# File saved successfully: PUB_RI_2000078.png
# File saved successfully: PUB_RI_2000079.png
# File saved successfully: PUB_RI_2000080.png
# File saved successfully: PUB_RI_2000081.png
# File saved successfully: PUB_RI_2000082.png
# File saved successfully: PUB_RI_2000083.png
# File saved successfully: PUB_RI_2000084.png
# File saved successfully: PUB_RI_2000085.png
# File saved successfully: PUB_RI_2000086.png
# File saved successfully: PUB_RI_2000087.png
# File saved successfully: PUB_RI_2000088.png
# File saved successfully: PUB_RI_2000089.png
# File saved successfully: PUB_RI_2000090.png
# File saved successfully: PUB_RI_2000091.png
# File saved successfully: PUB_RI_2000092.png
# File saved successfully: PUB_RI_2000093.png
# File saved successfully: PUB_RI_2000094.png
# File saved successfully: PUB_RI_2000095.png
# File saved successfully: PUB_RI_2000096.png
# File saved successfully: PUB_RI_2000097.png
# File saved successfully: PUB_RI_2000098.png
# File saved successfully: PUB_RI_2000099.png
# File saved successfully: PUB_RI_2000100.png
# File saved successfully: PUB_RI_2000101.png
# File saved successfully: PUB_RI_2000102.png
# File saved successfully: PUB_RI_2000103.png
# File saved successfully: PUB_RI_2000104.png
# File saved successfully: PUB_RI_2000105.png
# File saved successfully: PUB_RI_2000106.png
# File saved successfully: PUB_RI_2000107.png
# File saved successfully: PUB_RI_2000108.png
# File saved successfully: PUB_RI_2000109.png
# File saved successfully: PUB_RI_2000110.png
# File saved successfully: PUB_RI_2000111.png
# File saved successfully: PUB_RI_2000112.png
# File saved successfully: PUB_RI_2000113.png
# File saved successfully: PUB_RI_2000114.png
# File saved successfully: PUB_RI_2000115.png
# File saved successfully: PUB_RI_2000116.png
# File saved successfully: PUB_RI_2000117.png
# File saved successfully: PUB_RI_2000118.png
# File saved successfully: PUB_RI_2000119.png
# File saved successfully: PUB_RI_2000120.png
# File saved successfully: PUB_RI_2000121.png
# File saved successfully: PUB_RI_2000122.png
# File saved successfully: PUB_RI_2000123.png
# File saved successfully: PUB_RI_2000124.png
# File saved successfully: PUB_RI_2000125.png
# File saved successfully: PUB_RI_2000126.png
# File saved successfully: PUB_RI_2000127.png
# File saved successfully: PUB_RI_2000128.png
# File saved successfully: PUB_RI_2000129.png
# File saved successfully: PUB_RI_2000130.png
# File saved successfully: PUB_RI_2000131.png
# File saved successfully: PUB_RI_2000132.png
# File saved successfully: PUB_RI_2000133.png
# File saved successfully: PUB_RI_2000134.png
# File saved successfully: PUB_RI_2000135.png
# File saved successfully: PUB_RI_2000136.png
# File saved successfully: PUB_RI_2000137.png
# File saved successfully: PUB_RI_2000138.png
# File saved successfully: PUB_RI_2000139.png
# File saved successfully: PUB_RI_2000140.png
# File saved successfully: PUB_RI_2000141.png
# File saved successfully: PUB_RI_2000142.png
# File saved successfully: PUB_RI_2000143.png
# File saved successfully: PUB_RI_2000144.png
# File saved successfully: PUB_RI_2000145.png
# File saved successfully: PUB_RI_2000146.png
# File saved successfully: PUB_RI_2000147.png
# File saved successfully: PUB_RI_2000148.png
# File saved successfully: PUB_RI_2000149.png
# File saved successfully: PUB_RI_2000150.png
# File saved successfully: PUB_RI_2000151.png
# File saved successfully: PUB_RI_2000152.png
# File saved successfully: PUB_RI_2000153.png
# File saved successfully: PUB_RI_2000154.png
# File saved successfully: PUB_RI_2000155.png
# File saved successfully: PUB_RI_2000156.png
# File saved successfully: PUB_RI_2000157.png
# File saved successfully: PUB_RI_2000158.png
# File saved successfully: PUB_RI_2000159.png
# File saved successfully: PUB_RI_2000160.png
# File saved successfully: PUB_RI_2000161.png
# File saved successfully: PUB_RI_2000162.png
# File saved successfully: PUB_RI_2000163.png
# File saved successfully: PUB_RI_2000164.png
# File saved successfully: PUB_RI_2000165.png
# File saved successfully: PUB_RI_2000166.png
# File saved successfully: PUB_RI_2000167.png
# File saved successfully: PUB_RI_2000168.png
# File saved successfully: PUB_RI_2000169.png
# File saved successfully: PUB_RI_2000170.png
# File saved successfully: PUB_RI_2000171.png
# File saved successfully: PUB_RI_2000172.png
# File saved successfully: PUB_RI_2000173.png
# File saved successfully: PUB_RI_2000174.png
# File saved successfully: PUB_RI_2000175.png
# File saved successfully: PUB_RI_2000176.png
# File saved successfully: PUB_RI_2000177.png
# File saved successfully: PUB_RI_2000178.png
# File saved successfully: PUB_RI_2000179.png
# File saved successfully: PUB_RI_2000180.png
# File saved successfully: PUB_RI_2000181.png
# File saved successfully: PUB_RI_2000182.png
# File saved successfully: PUB_RI_2000183.png
# File saved successfully: PUB_RI_2000184.png
# File saved successfully: PUB_RI_2000185.png
# File saved successfully: PUB_RI_2000186.png
# File saved successfully: PUB_RI_2000187.png
# File saved successfully: PUB_RI_2000188.png
# File saved successfully: PUB_RI_2000189.png
# File saved successfully: PUB_RI_2000190.png
# File saved successfully: PUB_RI_2000191.png
# File saved successfully: PUB_RI_2000192.png
# File saved successfully: PUB_RI_2000193.png
# File saved successfully: PUB_RI_2000194.png
# File saved successfully: PUB_RI_2000195.png
# File saved successfully: PUB_RI_2000196.png
# File saved successfully: PUB_RI_2000197.png
# File saved successfully: PUB_RI_2000198.png
# File saved successfully: PUB_RI_2000199.png
# File saved successfully: PUB_RI_2000200.png
# File saved successfully: PUB_RI_2000201.png
# File saved successfully: PUB_RI_2000202.png
# File saved successfully: PUB_RI_2000203.png
# File saved successfully: PUB_RI_2000204.png
# File saved successfully: PUB_RI_2000205.png
# File saved successfully: PUB_RI_2000206.png
# File saved successfully: PUB_RI_2000207.png
# File saved successfully: PUB_RI_2000208.png
# File saved successfully: PUB_RI_2000209.png
# File saved successfully: PUB_RI_2000210.png
# File saved successfully: PUB_RI_2000211.png
# File saved successfully: PUB_RI_2000212.png
# File saved successfully: PUB_RI_2000213.png
# File saved successfully: PUB_RI_2000214.png
# File saved successfully: PUB_RI_2000215.png
# File saved successfully: PUB_RI_2000216.png
# File saved successfully: PUB_RI_2000217.png
# File saved successfully: PUB_RI_2000218.png
# File saved successfully: PUB_RI_2000219.png
# File saved successfully: PUB_RI_2000220.png
# File saved successfully: PUB_RI_2000221.png
# File saved successfully: PUB_RI_2000222.png
# File saved successfully: PUB_RI_2000223.png
# File saved successfully: PUB_RI_2000224.png
# File saved successfully: PUB_RI_2000225.png
# File saved successfully: PUB_RI_2000226.png
# File saved successfully: PUB_RI_2000227.png
# File saved successfully: PUB_RI_2000228.png
# File saved successfully: PUB_RI_2000229.png
# File saved successfully: PUB_RI_2000230.png
# File saved successfully: PUB_RI_2000231.png
# File saved successfully: PUB_RI_2000232.png
# File saved successfully: PUB_RI_2000233.png
# File saved successfully: PUB_RI_2000234.png
# File saved successfully: PUB_RI_2000235.png
# File saved successfully: PUB_RI_2000236.png
# File saved successfully: PUB_RI_2000237.png
# File saved successfully: PUB_RI_2000238.png
# File saved successfully: PUB_RI_2000239.png
# File saved successfully: PUB_RI_2000240.png
# File saved successfully: PUB_RI_2000241.png
# File saved successfully: PUB_RI_2000242.png
# File saved successfully: PUB_RI_2000243.png
# File saved successfully: PUB_RI_2000244.png
# File saved successfully: PUB_RI_2000245.png
# File saved successfully: PUB_RI_2000246.png
# File saved successfully: PUB_RI_2000247.png
# File saved successfully: PUB_RI_2000248.png
# File saved successfully: PUB_RI_2000249.png
# File saved successfully: PUB_RI_2000250.png
# File saved successfully: PUB_RI_2000251.png
# File saved successfully: PUB_RI_2000252.png
# File saved successfully: PUB_RI_2000253.png
# File saved successfully: PUB_RI_2000254.png
# File saved successfully: PUB_RI_2000255.png
# File saved successfully: PUB_RI_2000256.png
# File saved successfully: PUB_RI_2000257.png
# File saved successfully: PUB_RI_2000258.png
# File saved successfully: PUB_RI_2000259.png
# File saved successfully: PUB_RI_2000260.png
# File saved successfully: PUB_RI_2000261.png
# File saved successfully: PUB_RI_2000262.png
# File saved successfully: PUB_RI_2000263.png
# File saved successfully: PUB_RI_2000264.png
# File saved successfully: PUB_RI_2000265.png
# File saved successfully: PUB_RI_2000266.png
# File saved successfully: PUB_RI_2000267.png
# File saved successfully: PUB_RI_2000268.png
# File saved successfully: PUB_RI_2000269.png
# File saved successfully: PUB_RI_2000270.png
# File saved successfully: PUB_RI_2000271.png
# File saved successfully: PUB_RI_2000272.png
# File saved successfully: PUB_RI_2000273.png
# File saved successfully: PUB_RI_2000274.png
# File saved successfully: PUB_RI_2000275.png
# File saved successfully: PUB_RI_2000276.png
# File saved successfully: PUB_RI_2000277.png
# File saved successfully: PUB_RI_2000278.png
# File saved successfully: PUB_RI_2000279.png
# File saved successfully: PUB_RI_2000280.png
# File saved successfully: PUB_RI_2000281.png
# File saved successfully: PUB_RI_2000282.png
# File saved successfully: PUB_RI_2000283.png
# File saved successfully: PUB_RI_2000284.png
# File saved successfully: PUB_RI_2000285.png
# File saved successfully: PUB_RI_2000286.png
# File saved successfully: PUB_RI_2000287.png
# File saved successfully: PUB_RI_2000288.png
# File saved successfully: PUB_RI_2000289.png
# File saved successfully: PUB_RI_2000290.png
# File saved successfully: PUB_RI_2000291.png
# File saved successfully: PUB_RI_2000292.png
# File saved successfully: PUB_RI_2000293.png
# File saved successfully: PUB_RI_2000294.png
# File saved successfully: PUB_RI_2000295.png
# File saved successfully: PUB_RI_2000296.png
# File saved successfully: PUB_RI_2000297.png
# File saved successfully: PUB_RI_2000298.png
# File saved successfully: PUB_RI_2000299.png
# File saved successfully: PUB_RI_2000300.png
# File saved successfully: PUB_RI_2000301.png
# File saved successfully: PUB_RI_2000302.png
# File saved successfully: PUB_RI_2000303.png
# File saved successfully: PUB_RI_2000304.png
# File saved successfully: PUB_RI_2000305.png
# File saved successfully: PUB_RI_2000306.png
# File saved successfully: PUB_RI_2000307.png
# File saved successfully: PUB_RI_2000308.png
# File saved successfully: PUB_RI_2000309.png
# File saved successfully: PUB_RI_2000310.png
# File saved successfully: PUB_RI_2000311.png
# File saved successfully: PUB_RI_2000312.png
# File saved successfully: PUB_RI_2000313.png
# File saved successfully: PUB_RI_2000314.png
# File saved successfully: PUB_RI_2000315.png
# File saved successfully: PUB_RI_2000316.png
# File saved successfully: PUB_RI_2000317.png
# File saved successfully: PUB_RI_2000318.png
# File saved successfully: PUB_RI_2000319.png
# File saved successfully: PUB_RI_2000320.png
# File saved successfully: PUB_RI_2000321.png
# File saved successfully: PUB_RI_2000322.png
# File saved successfully: PUB_RI_2000323.png
# File saved successfully: PUB_RI_2000324.png
# File saved successfully: PUB_RI_2000325.png
# File saved successfully: PUB_RI_2000326.png
# File saved successfully: PUB_RI_2000327.png
# File saved successfully: PUB_RI_2000328.png
# File saved successfully: PUB_RI_2000329.png
# File saved successfully: PUB_RI_2000330.png
# File saved successfully: PUB_RI_2000331.png
# File saved successfully: PUB_RI_2000332.png
# File saved successfully: PUB_RI_2000333.png
# File saved successfully: PUB_RI_2000334.png
# File saved successfully: PUB_RI_2000335.png
# File saved successfully: PUB_RI_2000336.png
# File saved successfully: PUB_RI_2000337.png
# File saved successfully: PUB_RI_2000338.png
# File saved successfully: PUB_RI_2000339.png
# File saved successfully: PUB_RI_2000340.png
# File saved successfully: PUB_RI_2000341.png
# File saved successfully: PUB_RI_2000342.png
# File saved successfully: PUB_RI_2000343.png
# File saved successfully: PUB_RI_2000344.png
# File saved successfully: PUB_RI_2000345.png
# File saved successfully: PUB_RI_2000346.png
# File saved successfully: PUB_RI_2000347.png
# File saved successfully: PUB_RI_2000348.png
# File saved successfully: PUB_RI_2000349.png
# File saved successfully: PUB_RI_2000350.png
# File saved successfully: PUB_RI_2000351.png
# File saved successfully: PUB_RI_2000352.png
# File saved successfully: PUB_RI_2000353.png
# File saved successfully: PUB_RI_2000354.png
# File saved successfully: PUB_RI_2000355.png
# File saved successfully: PUB_RI_2000356.png
# File saved successfully: PUB_RI_2000357.png
# File saved successfully: PUB_RI_2000358.png
# File saved successfully: PUB_RI_2000359.png
# File saved successfully: PUB_RO_2000360.png
# File saved successfully: PUB_RO_2000361.png
# File saved successfully: PUB_RO_2000362.png
# File saved successfully: PUB_RO_2000363.png
# File saved successfully: PUB_RO_2000364.png
# File saved successfully: PUB_RO_2000365.png
# File saved successfully: PUB_RO_2000366.png
# File saved successfully: PUB_RO_2000367.png
# File saved successfully: PUB_RO_2000368.png
# File saved successfully: PUB_RO_2000369.png
# File saved successfully: PUB_RO_2000370.png
# File saved successfully: PUB_RO_2000371.png
# File saved successfully: PUB_RO_2000372.png
# File saved successfully: PUB_RO_2000373.png
# File saved successfully: PUB_RO_2000374.png
# File saved successfully: PUB_RO_2000375.png
# File saved successfully: PUB_RO_2000376.png
# File saved successfully: PUB_RO_2000377.png
# File saved successfully: PUB_RO_2000378.png
# File saved successfully: PUB_RO_2000379.png
# File saved successfully: PUB_RO_2000380.png
# File saved successfully: PUB_RO_2000381.png
# File saved successfully: PUB_RO_2000382.png
# File saved successfully: PUB_RO_2000383.png
# File saved successfully: PUB_RO_2000384.png
# File saved successfully: PUB_RO_2000385.png
# File saved successfully: PUB_RO_2000386.png
# File saved successfully: PUB_RO_2000387.png
# File saved successfully: PUB_RO_2000388.png
# File saved successfully: PUB_RO_2000389.png
# File saved successfully: PUB_RO_2000390.png
# File saved successfully: PUB_RO_2000391.png
# File saved successfully: PUB_RO_2000392.png
# File saved successfully: PUB_RO_2000393.png
# File saved successfully: PUB_RO_2000394.png
# File saved successfully: PUB_RO_2000395.png
# File saved successfully: PUB_RO_2000396.png
# File saved successfully: PUB_RO_2000397.png
# File saved successfully: PUB_RO_2000398.png
# File saved successfully: PUB_RO_2000399.png
# File saved successfully: PUB_RO_2000400.png
# File saved successfully: PUB_RO_2000401.png
# File saved successfully: PUB_RO_2000402.png
# File saved successfully: PUB_RO_2000403.png
# File saved successfully: PUB_RO_2000404.png
# File saved successfully: PUB_RO_2000405.png
# File saved successfully: PUB_RO_2000406.png
# File saved successfully: PUB_RO_2000407.png
# File saved successfully: PUB_RO_2000408.png
# File saved successfully: PUB_RO_2000409.png
# File saved successfully: PUB_RO_2000410.png
# File saved successfully: PUB_RO_2000411.png
# File saved successfully: PUB_RO_2000412.png
# File saved successfully: PUB_RO_2000413.png
# File saved successfully: PUB_RO_2000414.png
# File saved successfully: PUB_RO_2000415.png
# File saved successfully: PUB_RO_2000416.png
# File saved successfully: PUB_RO_2000417.png
# File saved successfully: PUB_RO_2000418.png
# File saved successfully: PUB_RO_2000419.png
# File saved successfully: PUB_RO_2000420.png
# File saved successfully: PUB_RO_2000421.png
# File saved successfully: PUB_RO_2000422.png
# File saved successfully: PUB_RO_2000423.png
# File saved successfully: PUB_RO_2000424.png
# File saved successfully: PUB_RO_2000425.png
# File saved successfully: PUB_RO_2000426.png
# File saved successfully: PUB_RO_2000427.png
# File saved successfully: PUB_RO_2000428.png
# File saved successfully: PUB_RO_2000429.png
# File saved successfully: PUB_RO_2000430.png
# File saved successfully: PUB_RO_2000431.png
# File saved successfully: PUB_RO_2000432.png
# File saved successfully: PUB_RO_2000433.png
# File saved successfully: PUB_RO_2000434.png
# File saved successfully: PUB_RO_2000435.png
# File saved successfully: PUB_RO_2000436.png
# File saved successfully: PUB_RO_2000437.png
# File saved successfully: PUB_RO_2000438.png
# File saved successfully: PUB_RO_2000439.png
# File saved successfully: PUB_RO_2000440.png
# File saved successfully: PUB_RO_2000441.png
# File saved successfully: PUB_RO_2000442.png
# File saved successfully: PUB_RO_2000443.png
# File saved successfully: PUB_RO_2000444.png
# File saved successfully: PUB_RO_2000445.png
# File saved successfully: PUB_RO_2000446.png
# File saved successfully: PUB_RO_2000447.png
# File saved successfully: PUB_RO_2000448.png
# File saved successfully: PUB_RO_2000449.png
# File saved successfully: PUB_RO_2000450.png
# File saved successfully: PUB_RO_2000451.png
# File saved successfully: PUB_RO_2000452.png
# File saved successfully: PUB_RO_2000453.png
# File saved successfully: PUB_RO_2000454.png
# File saved successfully: PUB_RO_2000455.png
# File saved successfully: PUB_RO_2000456.png
# File saved successfully: PUB_RO_2000457.png
# File saved successfully: PUB_RO_2000458.png
# File saved successfully: PUB_RO_2000459.png
# File saved successfully: PUB_RO_2000460.png
# File saved successfully: PUB_RO_2000461.png
# File saved successfully: PUB_RO_2000462.png
# File saved successfully: PUB_RO_2000463.png
# File saved successfully: PUB_RO_2000464.png
# File saved successfully: PUB_RO_2000465.png
# File saved successfully: PUB_RO_2000466.png
# File saved successfully: PUB_RO_2000467.png
# File saved successfully: PUB_RO_2000468.png
# File saved successfully: PUB_RO_2000469.png
# File saved successfully: PUB_RO_2000470.png
# File saved successfully: PUB_RO_2000471.png
# File saved successfully: PUB_RO_2000472.png
# File saved successfully: PUB_RO_2000473.png
# File saved successfully: PUB_RO_2000474.png
# File saved successfully: PUB_RO_2000475.png
# File saved successfully: PUB_RO_2000476.png
# File saved successfully: PUB_RO_2000477.png
# File saved successfully: PUB_RO_2000478.png
# File saved successfully: PUB_RO_2000479.png
# File saved successfully: PUB_RO_2000480.png
# File saved successfully: PUB_RO_2000481.png
# File saved successfully: PUB_RO_2000482.png
# File saved successfully: PUB_RO_2000483.png
# File saved successfully: PUB_RO_2000484.png
# File saved successfully: PUB_RO_2000485.png
# File saved successfully: PUB_RO_2000486.png
# File saved successfully: PUB_RO_2000487.png
# File saved successfully: PUB_RO_2000488.png
# File saved successfully: PUB_RO_2000489.png
# File saved successfully: PUB_RO_2000490.png
# File saved successfully: PUB_RO_2000491.png
# File saved successfully: PUB_RO_2000492.png
# File saved successfully: PUB_RO_2000493.png
# File saved successfully: PUB_RO_2000494.png
# File saved successfully: PUB_RO_2000495.png
# File saved successfully: PUB_RO_2000496.png
# File saved successfully: PUB_RO_2000497.png
# File saved successfully: PUB_RO_2000498.png
# File saved successfully: PUB_RO_2000499.png
# File saved successfully: PUB_RO_2000500.png
# File saved successfully: PUB_RO_2000501.png
# File saved successfully: PUB_RO_2000502.png
# File saved successfully: PUB_RO_2000503.png
# File saved successfully: PUB_RO_2000504.png
# File saved successfully: PUB_RO_2000505.png
# File saved successfully: PUB_RO_2000506.png
# File saved successfully: PUB_RO_2000507.png
# File saved successfully: PUB_RO_2000508.png
# File saved successfully: PUB_RO_2000509.png
# File saved successfully: PUB_RO_2000510.png
# File saved successfully: PUB_RO_2000511.png
# File saved successfully: PUB_RO_2000512.png
# File saved successfully: PUB_RO_2000513.png
# File saved successfully: PUB_RO_2000514.png
# File saved successfully: PUB_RO_2000515.png
# File saved successfully: PUB_RO_2000516.png
# File saved successfully: PUB_RO_2000517.png
# File saved successfully: PUB_RO_2000518.png
# File saved successfully: PUB_RO_2000519.png
# File saved successfully: PUB_RO_2000520.png
# File saved successfully: PUB_RO_2000521.png
# File saved successfully: PUB_RO_2000522.png
# File saved successfully: PUB_RO_2000523.png
# File saved successfully: PUB_RO_2000524.png
# File saved successfully: PUB_RO_2000525.png
# File saved successfully: PUB_RO_2000526.png
# File saved successfully: PUB_RO_2000527.png
# File saved successfully: PUB_RO_2000528.png
# File saved successfully: PUB_RO_2000529.png
# File saved successfully: PUB_RO_2000530.png
# File saved successfully: PUB_RO_2000531.png
# File saved successfully: PUB_RO_2000532.png
# File saved successfully: PUB_RO_2000533.png
# File saved successfully: PUB_RO_2000534.png
# File saved successfully: PUB_RO_2000535.png
# File saved successfully: PUB_RO_2000536.png
# File saved successfully: PUB_RO_2000537.png
# File saved successfully: PUB_RO_2000538.png
# File saved successfully: PUB_RO_2000539.png
# File saved successfully: PUB_RO_2000540.png
# File saved successfully: PUB_RO_2000541.png
# File saved successfully: PUB_RO_2000542.png
# File saved successfully: PUB_RO_2000543.png
# File saved successfully: PUB_RO_2000544.png
# File saved successfully: PUB_RO_2000545.png
# File saved successfully: PUB_RO_2000546.png
# File saved successfully: PUB_RO_2000547.png
# File saved successfully: PUB_RO_2000548.png
# File saved successfully: PUB_RO_2000549.png
# File saved successfully: PUB_RO_2000550.png
# File saved successfully: PUB_RO_2000551.png
# File saved successfully: PUB_RO_2000552.png
# File saved successfully: PUB_RO_2000553.png
# File saved successfully: PUB_RO_2000554.png
# File saved successfully: PUB_RO_2000555.png
# File saved successfully: PUB_RO_2000556.png
# File saved successfully: PUB_RO_2000557.png
# File saved successfully: PUB_RO_2000558.png
# File saved successfully: PUB_RO_2000559.png
# File saved successfully: PUB_RO_2000560.png
# File saved successfully: PUB_RO_2000561.png
# File saved successfully: PUB_RO_2000562.png
# File saved successfully: PUB_RO_2000563.png
# File saved successfully: PUB_RO_2000564.png
# File saved successfully: PUB_RO_2000565.png
# File saved successfully: PUB_RO_2000566.png
# File saved successfully: PUB_RO_2000567.png
# File saved successfully: PUB_RO_2000568.png
# File saved successfully: PUB_RO_2000569.png
# File saved successfully: PUB_RO_2000570.png
# File saved successfully: PUB_RO_2000571.png
# File saved successfully: PUB_RO_2000572.png
# File saved successfully: PUB_RO_2000573.png
# File saved successfully: PUB_RO_2000574.png
# File saved successfully: PUB_RO_2000575.png
# File saved successfully: PUB_RO_2000576.png
# File saved successfully: PUB_RO_2000577.png
# File saved successfully: PUB_RO_2000578.png
# File saved successfully: PUB_RO_2000579.png
# File saved successfully: PUB_RO_2000580.png
# File saved successfully: PUB_RO_2000581.png
# File saved successfully: PUB_RO_2000582.png
# File saved successfully: PUB_RO_2000583.png
# File saved successfully: PUB_RO_2000584.png
# File saved successfully: PUB_RO_2000585.png
# File saved successfully: PUB_RO_2000586.png
# File saved successfully: PUB_RO_2000587.png
# File saved successfully: PUB_RO_2000588.png
# File saved successfully: PUB_RO_2000589.png
# File saved successfully: PUB_RO_2000590.png
# File saved successfully: PUB_RO_2000591.png
# File saved successfully: PUB_RO_2000592.png
# File saved successfully: PUB_RO_2000593.png
# File saved successfully: PUB_RO_2000594.png
# File saved successfully: PUB_RO_2000595.png
# File saved successfully: PUB_RO_2000596.png
# File saved successfully: PUB_RO_2000597.png
# File saved successfully: PUB_RO_2000598.png
# File saved successfully: PUB_RO_2000599.png
# File saved successfully: PUB_RO_2000600.png
# File saved successfully: PUB_RO_2000601.png
# File saved successfully: PUB_RO_2000602.png
# File saved successfully: PUB_RO_2000603.png
# File saved successfully: PUB_RO_2000604.png
# File saved successfully: PUB_RO_2000605.png
# File saved successfully: PUB_RO_2000606.png
# File saved successfully: PUB_RO_2000607.png
# File saved successfully: PUB_RO_2000608.png
# File saved successfully: PUB_RO_2000609.png
# File saved successfully: PUB_RO_2000610.png
# File saved successfully: PUB_RO_2000611.png
# File saved successfully: PUB_RO_2000612.png
# File saved successfully: PUB_RO_2000613.png
# File saved successfully: PUB_RO_2000614.png
# File saved successfully: PUB_RO_2000615.png
# File saved successfully: PUB_RO_2000616.png
# File saved successfully: PUB_RO_2000617.png
# File saved successfully: PUB_RO_2000618.png
# File saved successfully: PUB_RO_2000619.png
# File saved successfully: PUB_RO_2000620.png
# File saved successfully: PUB_RO_2000621.png
# File saved successfully: PUB_RO_2000622.png
# File saved successfully: PUB_RO_2000623.png
# File saved successfully: PUB_RO_2000624.png
# File saved successfully: PUB_RO_2000625.png
# File saved successfully: PUB_RO_2000626.png
# File saved successfully: PUB_RO_2000627.png
# File saved successfully: PUB_RO_2000628.png
# File saved successfully: PUB_RO_2000629.png
# File saved successfully: PUB_RO_2000630.png
# File saved successfully: PUB_RO_2000631.png
# File saved successfully: PUB_RO_2000632.png
# File saved successfully: PUB_RO_2000633.png
# File saved successfully: PUB_RO_2000634.png
# File saved successfully: PUB_RO_2000635.png
# File saved successfully: PUB_RO_2000636.png
# File saved successfully: PUB_RO_2000637.png
# File saved successfully: PUB_RO_2000638.png
# File saved successfully: PUB_RO_2000639.png
# File saved successfully: PUB_RO_2000640.png
# File saved successfully: PUB_RO_2000641.png
# File saved successfully: PUB_RO_2000642.png
# File saved successfully: PUB_RO_2000643.png
# File saved successfully: PUB_RO_2000644.png
# File saved successfully: PUB_RO_2000645.png
# File saved successfully: PUB_RO_2000646.png
# File saved successfully: PUB_RO_2000647.png
# File saved successfully: PUB_RO_2000648.png
# File saved successfully: PUB_RO_2000649.png
# File saved successfully: PUB_RO_2000650.png
# File saved successfully: PUB_RO_2000651.png
# File saved successfully: PUB_RO_2000652.png
# File saved successfully: PUB_RO_2000653.png
# File saved successfully: PUB_RO_2000654.png
# File saved successfully: PUB_RO_2000655.png
# File saved successfully: PUB_RO_2000656.png
# File saved successfully: PUB_RO_2000657.png
# File saved successfully: PUB_RO_2000658.png
# File saved successfully: PUB_RO_2000659.png
# File saved successfully: PUB_RO_2000660.png
# File saved successfully: PUB_RO_2000661.png
# File saved successfully: PUB_RO_2000662.png
# File saved successfully: PUB_RO_2000663.png
# File saved successfully: PUB_RO_2000664.png
# File saved successfully: PUB_RO_2000665.png
# File saved successfully: PUB_RO_2000666.png
# File saved successfully: PUB_RO_2000667.png
# File saved successfully: PUB_RO_2000668.png
# File saved successfully: PUB_RO_2000669.png
# File saved successfully: PUB_RO_2000670.png
# File saved successfully: PUB_RO_2000671.png
# File saved successfully: PUB_RO_2000672.png
# File saved successfully: PUB_RO_2000673.png
# File saved successfully: PUB_RO_2000674.png
# File saved successfully: PUB_RO_2000675.png
# File saved successfully: PUB_RO_2000676.png
# File saved successfully: PUB_RO_2000677.png
# File saved successfully: PUB_RO_2000678.png
# File saved successfully: PUB_RO_2000679.png
# File saved successfully: PUB_RO_2000680.png
# File saved successfully: PUB_RO_2000681.png
# File saved successfully: PUB_RO_2000682.png
# File saved successfully: PUB_RO_2000683.png
# File saved successfully: PUB_RO_2000684.png
# File saved successfully: PUB_RO_2000685.png
# File saved successfully: PUB_RO_2000686.png
# File saved successfully: PUB_RO_2000687.png
# File saved successfully: PUB_RO_2000688.png
# File saved successfully: PUB_RO_2000689.png
# File saved successfully: PUB_RO_2000690.png
# File saved successfully: PUB_RO_2000691.png
# File saved successfully: PUB_RO_2000692.png
# File saved successfully: PUB_RO_2000693.png
# File saved successfully: PUB_RO_2000694.png
# File saved successfully: PUB_RO_2000695.png
# File saved successfully: PUB_RO_2000696.png
# File saved successfully: PUB_RO_2000697.png
# File saved successfully: PUB_RO_2000698.png
# File saved successfully: PUB_RO_2000699.png
# File saved successfully: PUB_RO_2000700.png
# File saved successfully: PUB_RO_2000701.png
# File saved successfully: PUB_RO_2000702.png
# File saved successfully: PUB_RO_2000703.png
# File saved successfully: PUB_RO_2000704.png
# File saved successfully: PUB_RO_2000705.png
# File saved successfully: PUB_RO_2000706.png
# File saved successfully: PUB_RO_2000707.png
# File saved successfully: PUB_RO_2000708.png
# File saved successfully: PUB_RO_2000709.png
# File saved successfully: PUB_RO_2000710.png
# File saved successfully: PUB_RO_2000711.png
# File saved successfully: PUB_RO_2000712.png
# File saved successfully: PUB_RO_2000713.png
# File saved successfully: PUB_RO_2000714.png
# File saved successfully: PUB_RO_2000715.png
# File saved successfully: PUB_RO_2000716.png
# File saved successfully: PUB_RO_2000717.png
# File saved successfully: PUB_RO_2000718.png
# File saved successfully: PUB_RO_2000719.png
# '/kaggle/working/submission_file.zip'
